# %%
import pandas as pd

# %%
s = pd.Series({0:'a', 1:'b'})  #também pode ser passado apenas uma lista com os valores
s
# Out:
# 0    a
# 1    b
# dtype: object

# %%
scientists = pd.DataFrame(data={'Idade':[20,32,26],
                                'Área':['Física', 'Bio', 'Mat']},
                                 columns=['Idade', 'Área'],
                                 index=['Gabriel','Bruna','Paulo'])
scientists
# Out:
#          Idade    Área
# Gabriel     20  Física
# Bruna       32     Bio
# Paulo       26     Mat

# %%
f_row = scientists.loc['Gabriel']
f_row
# Out:
# Idade        20
# Área     Física
# Name: Gabriel, dtype: object

# %%
print(f_row.index)
print(f_row.values)
print(f_row.keys())
# Out:
# Index(['Idade', 'Área'], dtype='object')
# [20 'Física']
# Index(['Idade', 'Área'], dtype='object')

# %%
age = scientists['Idade']
age
# Out:
# Gabriel    20
# Bruna      32
# Paulo      26
# Name: Idade, dtype: int64

# %%
scientists = pd.read_csv('C:\ProjetosDS\pandas_for_everyone-master\data\scientists.csv')
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
ages = scientists['Age']
ages.describe()
# Out:
# count     8.000000
# mean     59.125000
# std      18.325918
# min      37.000000
# 25%      44.000000
# 50%      58.500000
# 75%      68.750000
# max      90.000000
# Name: Age, dtype: float64

# %%
print(ages > ages.mean())  #cria uma série de booleanos
ages[ages > ages.mean()]  #subseting com booleanos
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
scientists[scientists['Age'] > scientists['Age'].mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
born_dt = pd.to_datetime(scientists['Born'], format='%Y-%m-%d')
died_dt = pd.to_datetime(scientists['Died'], format='%Y-%m-%d')
scientists['born_dt'], scientists['died_dt'] = (born_dt, died_dt)
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
scientists['age_days'] = scientists['died_dt'] - scientists['born_dt']
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt   age_days
# 0 1920-07-25 1958-04-16 13779 days
# 1 1876-06-13 1937-10-16 22404 days
# 2 1820-05-12 1910-08-13 32964 days
# 3 1867-11-07 1934-07-04 24345 days
# 4 1907-05-27 1964-04-14 20777 days
# 5 1813-03-15 1858-06-16 16529 days
# 6 1912-06-23 1954-06-07 15324 days
# ...

# %% [markdown]
# ### Dropping Values

# %%
df = scientists.copy()
df.drop(['age_days'], axis=1, inplace=True)
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
scientists.to_csv('C:\ProjetosDS\pandas_for_everyone-master\data\df_save_test.csv')

# %%
df_age = scientists['Age'].to_frame()
df_age
# Out:
#    Age
# 0   37
# 1   61
# 2   90
# 3   66
# 4   56
# 5   45
# 6   41
# 7   77
